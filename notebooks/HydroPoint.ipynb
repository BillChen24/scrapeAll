# %%
import requests

# %%
requests.post(url, headers=headers)
# Out:
# <Response [200]>

# %%
url = 'http://xxfb.mwr.cn/hydroSearch/pointHydroInfo'

# Set the desired date for which you want to scrape the data
desired_date = '2023-05-17'

# Construct the request payload
payload = {
    'type': 'ALL',
    'subType': 'HOUR',
    'dateType': 'SINGLE',
    'date': desired_date,
}

# Set the necessary headers, including the modified cookie with the desired date
headers = {
    'Cookie': 'zhuzhan=27740876; __FT10000066={}-17-19-24; __NRU10000066=1684455564209; __RT10000066={}-17-19-24; JSESSIONID=15080A97970723EF8424B69193A89DB4'.format(desired_date, desired_date),
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
}

# Send the POST request with the modified headers and payload
response = requests.post(url, headers=headers, data=payload)

# %%
url = 'http://xxfb.mwr.cn/hydroSearch/pointHydroInfo'

# Set the necessary headers, including the modified cookie with the desired date
headers = {
    'Cookie': 'zhuzhan=27740876; __FT10000066=2022-05-18-17-19-24; __NRU10000066=1684455564209; __RT10000066=2022-05-18-17-19-24; JSESSIONID=15080A97970723EF8424B69193A89DB4',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
}

# Send the POST request with the modified headers and payload
response = requests.post(url, headers=headers)

# %%
# Process the response as needed
data = response.json()
# ... process the data here
data
# Out:
# {'message': 'ok',
#  'result': {'date': '2023年05月19日',
#   'code': 0,
#   'data': [{'dateTime': '2023-05-19',
#     'dyp': 1.0,
#     'lat': 0.0,
#     'lgt': 0.0,
#     'poiAddv': '河北省',
#     'poiBsnm': '内陆河                        ',
#     'rvnm': '内陆河                        ',
#     'stcd': '01920600',
#     'stnm': '大囫囵                        ',
#     'tm': '2023-05-19 08:00:00',
#     'webStlc': '冀-康保县                     ',
#     'wth': ' '},
#    {'dateTime': '2023-05-19',
#     'dyp': 0.0,
#     'lat': 0.0,
#     'lgt': 0.0,
#     'poiAddv': '吉林省',
#     'poiBsnm': '第二松花江                    ',
#     'rvnm': '汤河                          ',
#     'stcd': '10804800',
#     'stnm': '松树镇                        ',
#     'tm': '2023-05-19 08:00:00',
#     'webStlc': '吉-江源                       ',
#     'wth': '9'},
#    {'dateTime': '2023-05-19',
#     'dyp': 0.0,
#     'lat': 0.0,
#     'lgt': 0.0,
#     'poiAddv': '吉林省',
#     'poiBsnm': '第二松花江                    ',
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
desired_date = '2023-05-17'

# Set up Chrome options with headless mode
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')

# Set the desired date in the cookie
cookie = f'zhuzhan=27740876; __FT10000066={desired_date}-17-19-24; __NRU10000066=1684455564209; __RT10000066={desired_date}-17-19-24; JSESSIONID=15080A97970723EF8424B69193A89DB4'

# Add the modified cookie to Chrome options
chrome_options.add_argument(f'--cookie="{cookie}"')

# Create the WebDriver instance
driver = webdriver.Chrome('path/to/chromedriver', options=chrome_options)

# Navigate to the website
driver.get('http://xxfb.mwr.cn/hydroSearch/pointHydroInfo')

# Continue with scraping and interacting with the website as needed
# ...
