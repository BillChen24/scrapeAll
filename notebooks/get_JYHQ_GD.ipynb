# %%
import sys
import os
# setting path
sys.path.append(os.path.dirname(os.getcwd()))

# %%
import pandas as pd
import json
from src.getRaw.Guangdong.get_prov_jyhq import *

# %%
# 
# pm.gd.csg.cn (Chinese IP needed)
# inspect html element
# Network -> Command + R -> Find "jyhqData-json-YEAR.json."
# Right click -> copy -> Copy Response.

# %%
data_2015 = {
    "cxdlData": [
        "130888",
        "111913",
        "131038",
        "141014",
        "148981",
        "149843",
        "153376",
        "152477",
        "152616",
        "145314",
        "140816",
        "141414"
    ],
    "jjjcData": [
        "",
        "",
        "-3.49",
        "-3.5",
        "-3.47",
        "-13.06",
        "-9.49",
        "-10.74",
        "-7.28",
        "-4.22",
        "-8.44",
        ""
    ],
    "priceData": [
        "-7.36",
        "-7.34",
        "-6.11",
        "-6.15",
        "-6.18",
        "-8.84",
        "-7.86",
        "-8.2",
        "-7.26",
        "-6.03",
        "-7.7",
        "-7.18"
    ],
    "jjdlData": [
        "0",
        "0",
        "57000",
        "57000",
        "57000",
        "57000",
        "57000",
        "57000",
        "57000",
        "96550",
        "96550",
        "0"
    ]
}

data_2016 = {
    "cxdlData": [
        "267442",
        "185298",
        "209125",
        "207714",
        "226582",
        "224641",
        "233541",
        "238593",
        "247884",
        "239446",
        "255878",
        "261742"
    ],
    "jjjcData": [
        "",
        "",
        "-125.55",
        "-147.93",
        "-133.28",
        "-93.9",
        "-58.87",
        "-43.38",
        "-37.42",
        "",
        "",
        ""
    ],
    "priceData": [
        "-11.99",
        "-11.51",
        "-49.29",
        "-67.2",
        "-57.64",
        "-48.57",
        "-36.44",
        "-30.36",
        "-27.32",
        "-11.04",
        "-11.07",
        "-11.1"
    ],
    "jjdlData": [
        "0",
        "0",
        "105000",
        "145000",
        "140000",
        "187000",
        "266000",
        "355000",
        "400000",
        "0",
        "0",
        "0"
    ]
}

data_2017 = {
    "cxdlData": [
        "639096",
        "476384",
        "614634",
        "672825",
        "715148",
        "736292",
        "764805",
        "758898",
        "746975",
        "731422",
        "699779",
        "715490"
    ],
    "jjjcData": [
        "",
        "-145.5",
        "-189.45",
        "-101.5",
        "-45",
        "-48.15",
        "-115",
        "-40.5",
        "-42.6",
        "-65",
        "-37",
        "-39.45"
    ],
    "priceData": [
        "-64.74",
        "-81.5",
        "-96.69",
        "-72.81",
        "-59.49",
        "-60.47",
        "-78.33",
        "-57.5",
        "-57.51",
        "-64.59",
        "-54.25",
        "-55.73"
    ],
    "jjdlData": [
        "0",
        "129912",
        "216441",
        "202657",
        "246376",
        "248057",
        "282033",
        "324902",
        "355223",
        "395018",
        "412213",
        "382952"
    ]
}

data_2018 = {
    "cxdlData": [
        "807841",
        "483812",
        "803486",
        "883347",
        "996515",
        "978427",
        "1040094",
        "1028903",
        "1010793",
        "986788",
        "945886",
        "979599"
    ],
    "jjjcData": [
        "-36.5",
        "-46.5",
        "-41.5",
        "-43.95",
        "-42",
        "-39.3",
        "-43.35",
        "-41.05",
        "-42",
        "-37",
        "-34.75",
        "-34.5"
    ],
    "priceData": [
        "-64.29",
        "-64.53",
        "-64.47",
        "-66.68",
        "-67.42",
        "-65.31",
        "-67.01",
        "-66.14",
        "-66.03",
        "-64.92",
        "-63.83",
        "-64.96"
    ],
    "jjdlData": [
        "351581",
        "324078",
        "427345",
        "389895",
        "363422",
        "426843",
        "425031",
        "432293",
        "441895",
        "411789",
        "415432",
        "369617"
    ]
}

data_2019 = {
    "cxdlData": [
        "921285",
        "666163",
        "1027366",
        "1097838",
        "1173587",
        "1248617",
        "1299529",
        "1340386",
        "1315807",
        "972196",
        "1261859",
        "1272149"
    ],
    "jjjcData": [
        "-35.05",
        "-37.2",
        "-34.05",
        "-28.8",
        "-29.3",
        "-30.95",
        "-30.5",
        "-29.95",
        "-29.5",
        "-29",
        "-27.95",
        "-26.95"
    ],
    "priceData": [
        "-41.28",
        "-42.17",
        "-40.93",
        "-39.59",
        "-39.36",
        "-40.39",
        "-40.43",
        "-40.45",
        "-40.02",
        "-39.7",
        "-39.62",
        "-39.64"
    ],
    "jjdlData": [
        "434524",
        "285516",
        "489202",
        "461701",
        "552917",
        "497276",
        "486473",
        "468202",
        "509991",
        "406541",
        "495254",
        "455570"
    ]
}

data_2020 = {
    "cxdlData": [
        "1224682",
        "1330778",
        "1756867",
        "1823201",
        "1921876",
        "1902416",
        "2040890",
        "2011821",
        "1891278",
        "1910761",
        "1862866",
        "1943326"
    ],
    "jjjcData": [
        "-35",
        "-34.25",
        "-34.95",
        "-32.5",
        "-34",
        "-29.5",
        "-30",
        "-130",
        "-29",
        "-27.45",
        "-30.5",
        "-40.05"
    ],
    "priceData": [
        "-45.44",
        "-44.68",
        "-46.69",
        "-46.24",
        "-46.29",
        "-45.14",
        "-45.11",
        "-50.17",
        "-43.2",
        "-43.33",
        "-43.67",
        "-46.12"
    ],
    "jjdlData": [
        "179778",
        "297145",
        "48882",
        "106951",
        "120414",
        "230465",
        "268570",
        "78895",
        "521881",
        "469675",
        "509180",
        "432635"
    ]
}
data_2021 = {
    "cxdlData": [
        "1504925",
        "1064370",
        "1765081",
        "1811091",
        "1912567",
        "1908171",
        "2618942",
        "2441648",
        "2277818",
        "1944189",
        "1875542",
        "1859229"
    ],
    "jjjcData": [
        "-31.4",
        "-40.1",
        "-30.9",
        "-29.7",
        "-39.95",
        "-19.1",
        "-18",
        "-2.5",
        "0",
        "45.3",
        "554",
        "554"
    ],
    "priceData": [
        "-46.68",
        "-51.88",
        "-47.75",
        "-47.25",
        "-50.69",
        "-43.15",
        "-46.16",
        "-41.55",
        "-40.83",
        "-40.62",
        "-47.8",
        "-52.29"
    ],
    "jjdlData": [
        "735584",
        "393565",
        "604045",
        "639206",
        "496792",
        "819318",
        "223795",
        "375736",
        "365358",
        "287029",
        "13954",
        "1650"
    ]
}

data_2022 = {"cxdlData":["1964839","1566993","2417332","2377706","","","","","","","",""],
             "jjjcData":["","","","","","","","","","","",""],
             "priceData":["499.4","497.79","500.42","500.27","","","","","","","",""],
             "jjdlData":["0","0","0","0","","","","","","","",""]}

# %%
jyhq_path = 'C:\\Users\\Bill Chen\\Desktop\\UCSD Course\\MD Lab\\scrapeAll\\data\\raw\\Guangdong\\prov_month'

# %%
store_jyhq_GD(data_2015, 2015, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2015_GD.json!

# %%
store_jyhq_GD(data_2016, 2016, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2016_GD.json!

# %%
store_jyhq_GD(data_2017, 2017, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2017_GD.json!

# %%
store_jyhq_GD(data_2018, 2018, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2018_GD.json!

# %%
store_jyhq_GD(data_2019, 2019, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2019_GD.json!

# %%
store_jyhq_GD(data_2020, 2020, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2020_GD.json!

# %%
store_jyhq_GD(data_2021, 2021, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2021_GD.json!

# %%
store_jyhq_GD(data_2022, 2022, jyhq_path)
# Out:
# file saved in C:\Users\Bill Chen\Desktop\UCSD Course\MD Lab\scrapeAll\data\raw\Guangdong\prov_month\jyhq_2022_GD.json!
