# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Create an URL object
url = 'https://www.cctd.com.cn/show-46-167312-1.html'
# Create object page
page = requests.get(url, verify = False)
# Out:
# C:\Users\Bill Chen\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.cctd.com.cn'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
soup = BeautifulSoup(page.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>2017年5月份中国电煤价格指数 -  煤炭指数 - 中国煤炭市场网</title>
# <meta content="价格指数,中国,月份" name="keywords"/>
# <meta content=" 6月13日，国家发改委网站公布了2017年5月份全国电煤价格指数。5月份全国电煤价格指数为501 92元 吨，环比下降1 6%，环比变化连续五月呈现下降态势，同比上涨59 3%。  分省来看，5月电煤价格指数排在前三位的   " name="description"/>
# <meta content="width=1200, initial-scale=1" name="viewport"/>
# <meta content="ynn02ujLr2" name="baidu-site-verification"/>
# <meta content="32f8b21d50f811c03334c532c0b3bb23" name="360-site-verification"/>
# <link href="https://www.cctd.com.cn/statics/css/base_v2.css?v=0.1" rel="stylesheet" type="text/css"/>
# <script src="https://www.cctd.com.cn/statics/js/jquery-3.6.0.min.js" type="text/javascript"></script>
# <script src="https://www.cctd.com.cn/statics/js/jquery-migrate-1.4.1.min.js" type="text/javascript"></script>
# <script src="https://www.cctd.com.cn/statics/js/select.jquery.js" type="text/javascript"></script>
# <script src="https://www.cctd.com.cn/statics/js/menu_min.js" type="text/javascript"></script>
# <script>
# 		var _hmt = _hmt || [];
# 		(function() {
# 		  var hm = document.createElement("script");
# 		  hm.src = "https://hm.baidu.com/hm.js?594886944cf2480d17095af56ff618e2";
# 		  var s = document.getElementsByTagName("script")[0];
# 		  s.parentNode.insertBefore(hm, s);
# 		})();
# 		</script>
# </head>
# <body style="overflow-x:hidden">
# <!-- <div style="margin: 0;padding: 0; width: 100%; line-height: 0px;">
# 		<img src="https://www.cctd.com.cn/statics/images/jd100-2.jpg" width="100%">
# 	</div> -->
# <div class="header">
# <div class="w1200 m0">
# <div class="fl top"> <a href="/">CCTD中国煤炭市场网</a> |
# 					 2023-03-12 09:48 星期日				</div>
# <div class="fr top">
# <script type="text/javascript">
# 						document.write('<iframe src="https://www.cctd.com.cn/index.php?m=member&c=index&a=mini&forward=' + encodeURIComponent(location
# 								.href) +
# 							'&siteid=1" allowTransparency="true"  width="480" height="40" frameborder="0" scrolling="no" style="margin-right:10px"></iframe>'
# 						)
# 					</script>
# <style type="text/css">
#
#
# 						#app-box {
# 							display: none;
# 							position: absolute;
# 							z-index: 999;
# 						}
#
# 						.appdl {}
# 					</style>
# </div>
# <div class="cb"></div>
# </div>
# </div>
# <!--logo-->
# <div class="bg_eeeeee">
# <div class="w1200 m0">
# <table border="0" cellpadding="0" cellspacing="0" style="width: 100%; vertical-align: middle;height: 92px;">
# <tr>
# <td align="left"><a href="https://www.cctd.com.cn/"><img alt="锟叫癸拷煤炭锟叫筹拷锟斤拷" src="https://www.cctd.com.cn/statics/images/logo0913.jpg" width="270"/></a></td>
# <!-- <td align="center">
# 							 <a href="show-176-231097-1.html" target="_blank"><img src="https://www.cctd.com.cn/statics/images//20230216.gif" width="528"></a>
# 						</td> -->
# <td align="center"><a href="http://www.cctdvip.com/wrzs.html" target="_blank"><img src="https://www.cctd.com.cn/statics/images//wrzs.jpg" width="528"/></a></td>
# <td align="right"><img alt="锟叫癸拷煤炭锟叫筹拷锟斤拷" src="https://www.cctd.com.cn/statics/images/lxfs.jpg" width="300"/></td>
# </tr>
# </table>
# <div class="cl">
# </div>
# </div>
# </div>
# <!-- <td align="center"><a href="index.php?m=content&c=index&a=lists&catid=688" target="_blank"><img src="https://www.cctd.com.cn/statics/images//2021xj/2021xjzk.png" height="80"></a></td> -->
# <div class="cb"></div>
# <div class="navbg">
# <div style="width: 1250px; margin: 0px auto; overflow: hidden;">
# <table align="center" border="0" cellpadding="0" cellspacing="0" class="nav" style="width: 1250px;">
# <tr>
# <!-- <td>
# 							<a target="_blank"
# 									href="https://www.cctd.com.cn/index.php?m=content&c=index&a=lists&catid=170">中国煤炭运销协会</a>
# 						</td> -->
# <td><a href="/" target="_blank">首页</a></td>
# <td><a href="list-353-1.html" target="_blank">煤炭资讯</a></td>
# <td><a href="list-354-1.html" target="_blank">煤炭市场分析</a></td>
# <td style="background: url(https://www.cctd.com.cn/statics/images/OKKK.gif) no-repeat right 3px;"><a href="list-167-1.html" target="_blank">煤炭数据库</a></td>
# <td><a href="list-360-1.html" target="_blank">煤炭智库</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=520" target="_blank">煤炭价格中心</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=508" target="_blank">无烟煤</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=733" target="_blank">大数据研究院</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=705" target="_blank">聚焦双碳</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=614" target="_blank">动力煤期货</a></td>
# <td><a href="http://www.cctdcoal.com/" target="_blank">English</a></td>
# </tr>
# </table>
# </div>
# </div>
# <div class="nav_tow">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td style="background: url(https://www.cctd.com.cn/statics/images/0605/ppb.gif) no-repeat left; padding-left: 15px;"><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=732" target="_blank">品牌榜</a></td>
# <td style="background: url(https://www.cctd.com.cn/statics/images/0605/001.gif) no-repeat left; padding-left: 15px;"><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=725#01" target="_blank">数据服务</a></td>
# <!-- <td style="background: url(https://www.cctd.com.cn/statics/images/0605/002.png) no-repeat left; padding-left: 15px;"><a href="#">锟斤拷锟斤拷锟斤拷锟街匡拷山</a></td> -->
# <!-- <td style="background: url(https://www.cctd.com.cn/statics/images/0605/002.gif) no-repeat left; padding-left: 15px;"><a href="/minpage/bottom_1/zsyw.html" target="_blank">指数业务</a></td> -->
# <td style="background: url(https://www.cctd.com.cn/statics/images/0605/003.gif) no-repeat left; padding-left: 15px;"><a href="/index.php?m=content&amp;c=index&amp;a=lists&amp;catid=626" target="_blank">品牌会议</a></td>
# <td style="background: url(https://www.cctd.com.cn/statics/images/0605/004.gif) no-repeat left; padding-left: 15px;"><a href="http://www.cctdvip.com/" target="_blank">运销管理软件</a></td>
# <td style="background: url(https://www.cctd.com.cn/statics/images/0605/008.gif) no-repeat left; padding-left: 15px;"><a href="http://www.cctdvip.com/" target="_blank">智慧营销</a></td>
# <td style="background: url(https://www.cctd.com.cn/statics/images/0605/006.gif) no-repeat left; padding-left: 15px;"><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=723" target="_blank">智慧物流</a></td>
# <td style="background: url(https://www.cctd.com.cn/statics/images/0605/009.gif) no-repeat left; padding-left: 15px;"><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=724" target="_blank">煤市数字云图</a></td>
# </tr>
# </table>
# </div>
# <div class="cb"></div>
# <!--logo-->
# <div class="banner">
# <script language="javascript" src="https://www.cctd.com.cn/index.php?m=poster&amp;c=index&amp;a=show_poster&amp;id=1"></script>
# </div>
# <!-- header锟斤拷锟斤拷 --><link href="https://www.cctd.com.cn/statics/css/show.css?v=0.03" rel="stylesheet"/>
# <div class="zhuti">
# <div class="w780 fl mr20">
# <div class="fenge">
# <div class="fenge_l fl"></div>
# <div class="fenge_r fl"></div>
# </div>
# <div class="suipin">
# <a href="https://www.cctd.com.cn">首页</a>&gt;<b class="mowei"><a href="https://www.cctd.com.cn/list-9-1.html">资讯中心</a> &gt; <a href="https://www.cctd.com.cn/list-45-1.html">煤炭指数</a> &gt; <a href="https://www.cctd.com.cn/list-46-1.html">中国电煤价格指数</a> &gt;  正文</b>
# </div>
# <div class="news_show">
# <h1>2017年5月份中国电煤价格指数</h1>
# <div class="news_tool">
# <ul>
# <li>来源：国家发改委
# 					</li>
# <li>发布时间：2017-06-14 08:58:23</li>
# <!-- <li>点击：<span id="hits"></span> -->
# <li>字号【
# 							<a href="javascript:doZoom(14)">小</a>
# <a href="javascript:doZoom(16)">中</a>
# <a href="javascript:doZoom(18)">大</a> 】</li>
# <li>
# <span id="favorite">
# <a href="javascript:;" onclick="add_favorite('2017年5月份中国电煤价格指数');">收藏新闻</a>
# </span>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# 				$(document).ready(function() {
# 					$('.datetitle tr').addClass('odd');
# 					$('.datetitle tr:even').addClass('even');
# 				});
# 			</script>
# <script type="text/javascript">
# 				function doZoom(size) {
# 					var zoom = document.all ? document.all['Zoom'] : document.getElementById('Zoom');
# 					zoom.style.fontSize = size + 'px';
# 				}
# 			</script>
# <div id="Zoom">
# 				    6月13日，国家发改委网站公布了2017年5月份全国电煤价格指数。5月份全国电煤价格指数为501.92元/吨，环比下降1.6%，环比变化连续五月呈现下降态势，同比上涨59.3%。
# <div> </div>
# <div>    分省来看，5月电煤价格指数排在前三位的是广西、江西及湖南，分别为696.4元/吨、681.05元/吨、639.8元/吨，环比分别下降1.91%、1.33%、2.64%，同比涨幅分别为47.99%、68.09%、63.02%。<br/>
#  </div>
# <div style="text-align: center;"><img alt="" src="http://www.cctd.com.cn/uploadfile/2017/0614/20170614090348394.jpg" style="width: 616px; height: 248px;"/></div>
# <div>
# <div style="text-align: center;"><br/>
# <div id="table1" style="color: rgb(0, 0, 0); font-family: Simsun; font-size: medium;">2017年5月各价区电煤价格指数  单位：元/吨发布日期：2017/6/13<br/>
# <br/>
# <table border="1" class="listTable2" style="border-style: none; border-spacing: 1px; width: 540px; background-color: rgb(204, 204, 204);">
# <tbody>
# <tr>
# <th class="listTitle1" id="0,0" style="font-size: 12px; color: rgb(255, 255, 255); width: 95px; height: 26px; vertical-align: middle; padding-left: 5px; padding-right: 5px; background-color: rgb(105, 165, 230);">
# 		价区</th>
# <th class="listTitle1" id="0,1" style="font-size: 12px; color: rgb(255, 255, 255); width: 95px; height: 26px; vertical-align: middle; padding-left: 5px; padding-right: 5px; background-color: rgb(105, 165, 230);">
# 		本期</th>
# <th class="listTitle1" id="0,2" style="font-size: 12px; color: rgb(255, 255, 255); width: 95px; height: 26px; vertical-align: middle; padding-left: 5px; padding-right: 5px; background-color: rgb(105, 165, 230);">
# 		上期</th>
# <th class="listTitle1" id="0,4" style="font-size: 12px; color: rgb(255, 255, 255); width: 95px; height: 26px; vertical-align: middle; padding-left: 5px; padding-right: 5px; background-color: rgb(105, 165, 230);">
# 		环比</th>
# <th class="listTitle1" id="0,5" style="font-size: 12px; color: rgb(255, 255, 255); width: 94px; height: 26px; vertical-align: middle; padding-left: 5px; padding-right: 5px; background-color: rgb(105, 165, 230);">
# 		同比</th>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="1,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>全国</label></td>
# <td class="tdlistcontext" id="1,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>501.92</label></td>
# <td class="tdlistcontext" id="1,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>510.12</label></td>
# <td class="tdlistcontext" id="1,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-1.61%</label></td>
# <td class="tdlistcontext" id="1,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>59.34%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="2,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>天津市</label></td>
# <td class="tdlistcontext" id="2,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>538.56</label></td>
# <td class="tdlistcontext" id="2,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>550.81</label></td>
# <td class="tdlistcontext" id="2,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-2.22%</label></td>
# <td class="tdlistcontext" id="2,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>78.40%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="3,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>冀北</label></td>
# <td class="tdlistcontext" id="3,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>451.84</label></td>
# <td class="tdlistcontext" id="3,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>470.85</label></td>
# <td class="tdlistcontext" id="3,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-4.04%</label></td>
# <td class="tdlistcontext" id="3,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>70.90%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="4,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>冀南</label></td>
# <td class="tdlistcontext" id="4,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>474.49</label></td>
# <td class="tdlistcontext" id="4,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>490.92</label></td>
# <td class="tdlistcontext" id="4,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-3.35%</label></td>
# <td class="tdlistcontext" id="4,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>75.47%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="5,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>山西省</label></td>
# <td class="tdlistcontext" id="5,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>343.00</label></td>
# <td class="tdlistcontext" id="5,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>362.89</label></td>
# <td class="tdlistcontext" id="5,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-5.48%</label></td>
# <td class="tdlistcontext" id="5,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>69.11%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="6,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>蒙西</label></td>
# <td class="tdlistcontext" id="6,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>287.86</label></td>
# <td class="tdlistcontext" id="6,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>287.19</label></td>
# <td class="tdlistcontext" id="6,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>0.23%</label></td>
# <td class="tdlistcontext" id="6,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>82.47%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="7,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>蒙东</label></td>
# <td class="tdlistcontext" id="7,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>232.36</label></td>
# <td class="tdlistcontext" id="7,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>245.24</label></td>
# <td class="tdlistcontext" id="7,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-5.25%</label></td>
# <td class="tdlistcontext" id="7,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>16.59%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="8,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>辽宁省</label></td>
# <td class="tdlistcontext" id="8,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>505.38</label></td>
# <td class="tdlistcontext" id="8,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>517.94</label></td>
# <td class="tdlistcontext" id="8,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-2.42%</label></td>
# <td class="tdlistcontext" id="8,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>37.89%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="9,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>吉林省</label></td>
# <td class="tdlistcontext" id="9,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>464.82</label></td>
# <td class="tdlistcontext" id="9,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>470.00</label></td>
# <td class="tdlistcontext" id="9,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-1.10%</label></td>
# <td class="tdlistcontext" id="9,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>42.91%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="10,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>黑龙江省</label></td>
# <td class="tdlistcontext" id="10,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>435.05</label></td>
# <td class="tdlistcontext" id="10,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>428.73</label></td>
# <td class="tdlistcontext" id="10,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>1.47%</label></td>
# <td class="tdlistcontext" id="10,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>28.68%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="11,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>上海市</label></td>
# <td class="tdlistcontext" id="11,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>562.47</label></td>
# <td class="tdlistcontext" id="11,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>574.07</label></td>
# <td class="tdlistcontext" id="11,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-2.02%</label></td>
# <td class="tdlistcontext" id="11,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>55.54%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="12,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>江苏省</label></td>
# <td class="tdlistcontext" id="12,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>577.32</label></td>
# <td class="tdlistcontext" id="12,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>589.65</label></td>
# <td class="tdlistcontext" id="12,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-2.09%</label></td>
# <td class="tdlistcontext" id="12,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>59.86%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="13,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>浙江省</label></td>
# <td class="tdlistcontext" id="13,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>561.04</label></td>
# <td class="tdlistcontext" id="13,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>564.90</label></td>
# <td class="tdlistcontext" id="13,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-0.68%</label></td>
# <td class="tdlistcontext" id="13,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>45.59%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="14,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>安徽省</label></td>
# <td class="tdlistcontext" id="14,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>599.55</label></td>
# <td class="tdlistcontext" id="14,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>611.56</label></td>
# <td class="tdlistcontext" id="14,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-1.96%</label></td>
# <td class="tdlistcontext" id="14,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>59.45%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="15,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>福建省</label></td>
# <td class="tdlistcontext" id="15,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>577.83</label></td>
# <td class="tdlistcontext" id="15,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>589.87</label></td>
# <td class="tdlistcontext" id="15,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-2.04%</label></td>
# <td class="tdlistcontext" id="15,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>59.35%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="16,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>江西省</label></td>
# <td class="tdlistcontext" id="16,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>681.05</label></td>
# <td class="tdlistcontext" id="16,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>690.25</label></td>
# <td class="tdlistcontext" id="16,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-1.33%</label></td>
# <td class="tdlistcontext" id="16,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>68.09%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="17,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>山东省</label></td>
# <td class="tdlistcontext" id="17,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>581.36</label></td>
# <td class="tdlistcontext" id="17,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>587.27</label></td>
# <td class="tdlistcontext" id="17,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-1.01%</label></td>
# <td class="tdlistcontext" id="17,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>57.47%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="18,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>河南省</label></td>
# <td class="tdlistcontext" id="18,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>537.08</label></td>
# <td class="tdlistcontext" id="18,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>558.27</label></td>
# <td class="tdlistcontext" id="18,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-3.80%</label></td>
# <td class="tdlistcontext" id="18,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>64.50%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="19,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>湖北省</label></td>
# <td class="tdlistcontext" id="19,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>614.40</label></td>
# <td class="tdlistcontext" id="19,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>617.44</label></td>
# <td class="tdlistcontext" id="19,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-0.49%</label></td>
# <td class="tdlistcontext" id="19,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>71.07%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="20,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>湖南省</label></td>
# <td class="tdlistcontext" id="20,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>639.80</label></td>
# <td class="tdlistcontext" id="20,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>657.14</label></td>
# <td class="tdlistcontext" id="20,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-2.64%</label></td>
# <td class="tdlistcontext" id="20,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>63.02%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="21,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>广东省</label></td>
# <td class="tdlistcontext" id="21,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>617.01</label></td>
# <td class="tdlistcontext" id="21,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>628.19</label></td>
# <td class="tdlistcontext" id="21,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-1.78%</label></td>
# <td class="tdlistcontext" id="21,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>54.81%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="22,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>广西自治区</label></td>
# <td class="tdlistcontext" id="22,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>696.40</label></td>
# <td class="tdlistcontext" id="22,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>709.94</label></td>
# <td class="tdlistcontext" id="22,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-1.91%</label></td>
# <td class="tdlistcontext" id="22,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>47.99%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="23,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>海南省</label></td>
# <td class="tdlistcontext" id="23,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>580.48</label></td>
# <td class="tdlistcontext" id="23,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>579.57</label></td>
# <td class="tdlistcontext" id="23,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>0.16%</label></td>
# <td class="tdlistcontext" id="23,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>41.36%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="24,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>重庆市</label></td>
# <td class="tdlistcontext" id="24,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>608.50</label></td>
# <td class="tdlistcontext" id="24,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>602.67</label></td>
# <td class="tdlistcontext" id="24,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>0.97%</label></td>
# <td class="tdlistcontext" id="24,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>69.65%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="25,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>四川省</label></td>
# <td class="tdlistcontext" id="25,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>608.72</label></td>
# <td class="tdlistcontext" id="25,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>627.55</label></td>
# <td class="tdlistcontext" id="25,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-3.00%</label></td>
# <td class="tdlistcontext" id="25,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>82.43%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="26,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>贵州省</label></td>
# <td class="tdlistcontext" id="26,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>490.91</label></td>
# <td class="tdlistcontext" id="26,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>489.64</label></td>
# <td class="tdlistcontext" id="26,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>0.26%</label></td>
# <td class="tdlistcontext" id="26,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>58.50%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="27,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>云南省</label></td>
# <td class="tdlistcontext" id="27,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>465.94</label></td>
# <td class="tdlistcontext" id="27,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>450.36</label></td>
# <td class="tdlistcontext" id="27,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>3.46%</label></td>
# <td class="tdlistcontext" id="27,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>28.60%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="28,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>陕西省</label></td>
# <td class="tdlistcontext" id="28,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>434.04</label></td>
# <td class="tdlistcontext" id="28,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>467.93</label></td>
# <td class="tdlistcontext" id="28,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-7.24%</label></td>
# <td class="tdlistcontext" id="28,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>72.88%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="29,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>甘肃省</label></td>
# <td class="tdlistcontext" id="29,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>444.73</label></td>
# <td class="tdlistcontext" id="29,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>472.10</label></td>
# <td class="tdlistcontext" id="29,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-5.80%</label></td>
# <td class="tdlistcontext" id="29,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>75.16%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="30,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>青海省</label></td>
# <td class="tdlistcontext" id="30,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>508.94</label></td>
# <td class="tdlistcontext" id="30,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>499.48</label></td>
# <td class="tdlistcontext" id="30,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>1.89%</label></td>
# <td class="tdlistcontext" id="30,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>39.77%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="31,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>宁夏自治区</label></td>
# <td class="tdlistcontext" id="31,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>367.31</label></td>
# <td class="tdlistcontext" id="31,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>376.13</label></td>
# <td class="tdlistcontext" id="31,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>-2.34%</label></td>
# <td class="tdlistcontext" id="31,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>75.06%</label></td>
# </tr>
# <tr class="trlist1" style="background-color: rgb(255, 255, 255);">
# <td class="tdlistcontext" id="32,0" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>新疆自治区</label></td>
# <td class="tdlistcontext" id="32,1" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>187.05</label></td>
# <td class="tdlistcontext" id="32,2" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>182.88</label></td>
# <td class="tdlistcontext" id="32,4" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>2.28%</label></td>
# <td class="tdlistcontext" id="32,5" style="font-size: 12px; padding: 3px 5px; vertical-align: middle; height: 25px;"><label>19.00%</label></td>
# </tr>
# </tbody>
# </table>
# </div>
# <table style="color: rgb(0, 0, 0); font-family: Simsun; font-size: medium;">
# <tbody>
# <tr>
# <td><a style="text-align: left; font-size: 10px;">注：因燃煤机组停运，2017年4月份起不再监测发布北京市电煤价格指数</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <br/>
# <!-- 关键词-->
# <!-- -->
# <!--价格指数-->
# <!-- -->
# <!--中国-->
# <!-- -->
# <!--月份-->
# <!-- -->
# <!--内容关联投票-->
# </div>
# </div>
# <div style="text-align: center;">
# <!-- <img src="https://www.cctd.com.cn/statics/images/show_ewm.jpg" width="300" > -->
# <img src="https://www.cctd.com.cn/statics/images/ewm20220407.jpg" width="300"/>
# <p style="text-align: left;">发布人：</p>
# </div>
# <div class="bqsm">
# <p>中国煤炭市场网或与合作机构共同发布的全部内容及材料拥有版权等知识产权，受法律保护。未经中国煤炭市场网书面许可，任何单位及个人不得以任何方式对上述产品、信息进行使用、复制传播或与其它产品捆绑销售。</p>
# </div>
# <style type="text/css">
# 			.mzsm{  background: #ffffff; padding: 0px 20px; overflow: hidden; float: right; font-size: 12px; margin-bottom: 20px;}
# 		</style>
# <div class="mzsm">
# <p>免责声明：网站刊登CCTD认为可靠的已公开信息，对这些信息的准确性和完整性不作任何保证。CCTD所提供的信息，只供参考之用，不构成对任何人的投资建议。网站会员不应以此取代自己的独立判断，网站会员做出的任何决策与CCTD无关， CCTD及其雇员不对使用网站信息及其内容所引发的任何直接或间接损失负任何责任。</p>
# </div>
# <div class="news_show_foot">
# 			关键词：
# 			<a href="#">煤炭</a>
# <a href="#">指数</a>
# <a href="#">价格</a>
# <a href="#">动力煤</a>
# <a href="#">炼焦煤</a>
# <a class="r_top" href="#">返回顶端</a>
# </div>
# <div class="xgyd">
# <div class="fl" style="width:680px">
# <h2>相关阅读：</h2>
# <ul>
# <li>·
# 						<a href="https://www.cctd.com.cn/show-46-38542-1.html" target="_blank">2016年3月份中国电煤价格指数</a><span style="font-size:12px;float:right">2016-04-19</span></li>
# <li>·
# 						<a href="https://www.cctd.com.cn/show-46-40593-1.html" target="_blank">2016年4月份中国电煤价格指数</a><span style="font-size:12px;float:right">2016-05-16</span></li>
# <li>·
# 						<a href="https://www.cctd.com.cn/show-46-82120-1.html" target="_blank">2016年5月份中国电煤价格指数</a><span style="font-size:12px;float:right">2016-06-16</span></li>
# <li>·
# 						<a href="https://www.cctd.com.cn/show-46-144549-1.html" target="_blank">2016年6月份中国电煤价格指数</a><span style="font-size:12px;float:right">2016-07-15</span></li>
# <li>·
# 						<a href="https://www.cctd.com.cn/show-46-147143-1.html" target="_blank">2016年7月份中国电煤价格指数</a><span style="font-size:12px;float:right">2016-08-17</span></li>
# </ul>
# </div>
# </div>
# <div class="cb">
# </div>
# </div>
# <div class="w300 fl">
# <div class="w230 fl">
# <div class="hxqk">
# <div class="fxpl_bt"><span>新闻点击排名</span>
# <a href="list-10-1.html">more</a>
# </div>
# <ul>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-42-231639-1.html" target="_blank">CCTD：三月中下旬动力煤市场</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-176-231548-1.html" target="_blank">速读！政府工作报告这些内容与煤</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-42-231595-1.html" target="_blank">CCTD：乍暖还寒的煤炭市场</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-372-231550-1.html" target="_blank">一图速览2023年政府工作报告</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-42-231421-1.html" target="_blank">CCTD与您一起围炉话"煤"</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-42-231284-1.html" target="_blank">CCTD与您一起围炉话“煤”</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-16-231554-1.html" target="_blank">政府工作报告这样说能源！</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-42-231512-1.html" target="_blank">CCTD：2月国际煤价震荡下行</a>
# </li>
# <li>
# <div class="dian_b">•</div>
# <a href="https://www.cctd.com.cn/show-176-231561-1.html" target="_blank">全国人大代表杨会军：推动煤炭产</a>
# </li>
# </ul>
# </div>
# <!-- <div class="hxqk">
# 				<div class="fxpl_bt"><span>价格点击排名</span>
# 					<a href="list-145-1.html">more</a>
# 				</div>
#
# 								<ul>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-308-171787-1.html">2017年09月12日山西地区煤</a><b>09-12</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-317-183150-1.html">2018年08月03日黑龙江地区</a><b>08-03</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-318-183148-1.html">2018年08月03日湖南地区煤</a><b>08-03</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/index.php?m=content&c=index&a=show&catid=291&id=173060">2017年10月18日日照港煤炭</a><b>10-18</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-326-143068-1.html">2014-06-18重庆地区煤炭价</a><b>06-18</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-308-165985-1.html">2017-05-22山西地区煤炭价</a><b>05-22</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/index.php?m=content&c=index&a=show&catid=291&id=182751">2018年07月20日日照港煤炭</a><b>07-20</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-318-183504-1.html">2018年08月17日湖南地区煤</a><b>08-17</b></li>
# 									</ul>
#
# 			</div> -->
# <!-- <div class="hxqk">
# 				<div class="fxpl_bt"><span>数据点击排名</span>
# 					<a href="list-145-1.html">more</a>
# 				</div>
#
# 								<ul>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-308-171787-1.html">2017年09月12日山西地区煤</a><b>09-12</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-317-183150-1.html">2018年08月03日黑龙江地区</a><b>08-03</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-318-183148-1.html">2018年08月03日湖南地区煤</a><b>08-03</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/index.php?m=content&c=index&a=show&catid=291&id=173060">2017年10月18日日照港煤炭</a><b>10-18</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-326-143068-1.html">2014-06-18重庆地区煤炭价</a><b>06-18</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-308-165985-1.html">2017-05-22山西地区煤炭价</a><b>05-22</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/index.php?m=content&c=index&a=show&catid=291&id=182751">2018年07月20日日照港煤炭</a><b>07-20</b></li>
# 										<li>
# 						<div class="dian_b">&#8226;</div>
# 						<a target="_blank" href="https://www.cctd.com.cn/show-318-183504-1.html">2018年08月17日湖南地区煤</a><b>08-17</b></li>
# 									</ul>
#
# 			</div> -->
# <div class="hxqk">
# <ul>
# <li style="margin-bottom: 5px;"><a href="show-364-38064-1.html" target="_blank"><img alt="每周煤炭经济" src="https://www.cctd.com.cn/statics/images/gd/080401.jpg"/></a></li>
# <li style="margin-bottom: 5px;"><a href="show-364-38377-1.html" target="_blank"><img alt="中国煤炭市场" src="https://www.cctd.com.cn/statics/images/gd/080901.jpg"/></a></li>
# <li style="margin-bottom: 5px;"><a href="show-364-38383-1.html" target="_blank"><img alt="每周国际煤市" src="https://www.cctd.com.cn/statics/images/gd/080403.jpg"/></a></li>
# <li style="margin-bottom: 5px;"><a href="show-452-209887-1.html" target="_blank"><img alt="年度报告" src="https://www.cctd.com.cn/statics/images/gd/20220407ndbg.jpg"/></a></li>
# </ul>
# </div>
# <script src="https://www.cctd.com.cn/statics/js/jquery-ui-datepicker.js" type="text/javascript"></script>
# <link href="https://www.cctd.com.cn/statics/css/jquery-ui.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# 				$(function() {
# 					$("#datepicker").datepicker({
# 						showOtherMonths: true
# 					});
# 				});
# 			</script>
# <!--<div id="datepicker"></div>-->
# <div class="cb"></div>
# </div>
# </div>
# <div class="cb mb10">
# </div>
# </div>
# <script type="text/javascript">
#
# 	function show_ajax(obj) {
# 		var keywords = $(obj).text();
# 		var offset = $(obj).offset();
# 		var jsonitem = '';
# 		$.getJSON("https://www.cctd.com.cn/index.php?m=content&c=index&a=json_list&type=keyword&modelid=1&id=167312&keywords=" + encodeURIComponent(keywords),
# 			function(data) {
# 				var j = 1;
# 				var string = "<div class='point key-float'><div style='position:relative'><div class='arro'></div>";
# 				string += "<a href='JavaScript:;' onclick='$(this).parent().parent().remove();' hidefocus='true' class='close'><span>关闭</span></a><div class='contents f12'>";
# 				if(data != 0) {
# 					$.each(data, function(i, item) {
# 						j = i + 1;
# 						jsonitem += "<a href='" + item.url + "' target='_blank'>" + j + "、" + item.title + "</a><BR>";
#
# 					});
# 					string += jsonitem;
# 				} else {
# 					string += '没有找到相关的信息！';
# 				}
# 				string += "</div><span class='o1'></span><span class='o2'></span><span class='o3'></span><span class='o4'></span></div></div>";
# 				$(obj).after(string);
# 				$('.key-float').mouseover(
# 					function() {
# 						$(this).siblings().css({
# 							"z-index": 0
# 						})
# 						$(this).css({
# 							"z-index": 1001
# 						});
# 					}
# 				)
# 				$(obj).next().css({
# 					"left": +offset.left - 100,
# 					"top": +offset.top + $(obj).height() + 12
# 				});
# 			});
# 	}
#
# 	function add_favorite(title) {
# 		$.getJSON('https://www.cctd.com.cn/api.php?op=add_favorite&title=' + encodeURIComponent(title) + '&url=' + encodeURIComponent(location.href) + '&' + Math.random() + '&callback=?', function(data) {
# 			if(data.status == 1) {
# 				$("#favorite").html('收藏成功');
# 			} else {
# 				alert('请登录');
# 			}
# 		});
# 	}
#
# 	// $(function() {
# 	// 		$('#Article .content img').LoadImage(true, 660, 660, 'https://www.cctd.com.cn/statics/images/s_nopic.gif');
# 	// 	})
#
# </script>
# <script language="JavaScript" src="https://www.cctd.com.cn/api.php?op=count&amp;id=167312&amp;modelid=1"></script>
# <!-- foot开始 -->
# <style type="text/css">
# 	.bottom_v3 {
# 		background: #4285f4;
# 		min-height: 200px;
# 		border-top: #4285f4 2px solid;
# 		padding: 50px 0px 0px 0px;
# 		overflow: hidden;
# 	}
#
# 	.bottom_table {
# 		width: 830px;
# 	}
#
# 	.bottom_table tr td,
# 	th {
# 		color: #FFFFFF;
# 		text-align: left;
# 	}
#
# 	.bottom_table th {
# 		font-size: 16px;
# 		line-height: 4em;
# 		font-weight: bold;
# 	}
#
# 	.bottom_table td {
# 		font-size: 12px;
# 		line-height: 3em;
# 	}
#
# 	.bottom_table td a {
# 		color: #FFFFFF;
# 	}
#
# 	.bottom_table th a {
# 		color: #FFFFFF;
# 	}
# </style>
# <div class="bottom_v3">
# <div class="zhuti1">
# <table border="0" cellpadding="0" cellspacing="0" class="bottom_table" style="float: left; border-right:1px solid #FFFFFF ;">
# <tr>
# <th><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=720" target="_blank">CCTD是谁</a></th>
# <th><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=725#01" target="_blank">数据服务</a>
# </th>
# <th><a href="http://www.cctdvip.com/" target="_blank">智能数字矿山</a></th>
# <!-- <th><a target="_blank" href="https://www.cctd.com.cn/minpage/bottom_1/zsyw.html">指数业务</a></th> -->
# <th><a href="https://www.cctd.com.cn/index.php?m=content&amp;c=index&amp;a=lists&amp;catid=626" target="_blank">品牌会议</a>
# </th>
# <th><a href="http://www.cctdvip.com/" target="_blank">运销管理软件</a></th>
# </tr>
# <tr>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=720" target="_blank">关于CCTD</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=725#01" target="_blank">数据定制</a>
# </td>
# <td><a href="http://www.cctdvip.com/" target="_blank">数据融合</a></td>
# <!-- <td><a target="_blank" href="https://www.cctd.com.cn/minpage/bottom_1/zsyw.html">指数介绍</a></td> -->
# <td><a href="https://www.cctd.com.cn/index.php?m=content&amp;c=index&amp;a=lists&amp;catid=626" target="_blank">全国煤炭交易会</a>
# </td>
# <td><a href="http://www.cctdvip.com/yxgl.html" target="_blank">煤炭运销管理信息系统</a>
# </td>
# </tr>
# <tr>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=726" target="_blank">研究团队</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=725#03" target="_blank">产业数据库</a>
# </td>
# <td><a href="http://www.cctdvip.com/" target="_blank">算法研究</a></td>
# <!-- <td><a target="_blank" href="https://www.cctd.com.cn/minpage/bottom_1/zsyw.html#02">资源基础</a>
# 				</td> -->
# <td><a href="#">电话视频会议</a></td>
# <td><a href="http://www.cctdvip.com/wrzs.html" target="_blank">无人值守磅房</a>
# </td>
# </tr>
# <tr>
# <td><a href="#">年度指数报告</a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=725#04" target="_blank">周期类刊物和分析报告</a></td>
# <td><a href="http://www.cctdvip.com/" target="_blank">系统集成</a></td>
# <!-- <td><a target="_blank" href="https://www.cctd.com.cn/minpage/bottom_1/zsyw.html#03">指数业务</a>
# 				</td> -->
# <td></td>
# <td><a href="http://www.cctdvip.com/tcyc.html" target="_blank">筒仓远程装车</a>
# </td>
# </tr>
# <tr>
# <td></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=725#5" target="_blank">咨询服务</a></td>
# <td></td>
# <!-- <td><a target="_blank" href="https://www.cctd.com.cn/minpage/bottom_1/zsyw.html#04">项目案例</a>
# 				</td> -->
# <td><a href="#"></a></td>
# <td><a href="http://www.cctdvip.com/zdzc.html" target="_blank">智能化自动装车</a></td>
# </tr>
# <tr>
# <td><a href="#"></a></td>
# <td><a href="index.php?m=content&amp;c=index&amp;a=lists&amp;catid=725#6" target="_blank">考察活动</a></td>
# <td></td>
# <!-- <td><a target="_blank" href="https://www.cctd.com.cn/minpage/bottom_1/zsyw.html#05">指数编辑发布</a>
# 				</td>-->
# <td><a href="#"></a></td>
# <td><a href="http://www.cctdvip.com/" target="_blank">智慧营销支持</a></td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" style="float: right; width: 320px; margin-top: 25px;">
# <tr>
# <td>
# <p><img src="https://www.cctd.com.cn/statics/images/bottom/bottom-icon-CCTDlogo.png"/></p>
# <p style="font-size: 16px; line-height: 28px;margin-top: 30px;"><b>关注CCTD</b></p>
# <p class="bottom_v2_p" style="margin-top: 30px;">
# <img src="https://www.cctd.com.cn/statics/images/bottom/bottom-icon-01.png"/>
# <b>    010-6446 4669</b></p>
# <p class="bottom_v2_p"><img src="https://www.cctd.com.cn/statics/images/bottom/bottom-icon-02.png"/><b>    cctd@vip.sina.com</b>
# </p>
# </td>
# <!-- <td colspan="3" align="center" valign="top"></td> -->
# </tr>
# </table>
# </div>
# </div>
# <div class="foot">
# <table align="top" border="0" cellpadding="0" cellspacing="0" style="margin: 0px auto; width: 1360px;">
# <tr>
# <!-- <td valign="top" align="center"><img src="https://www.cctd.com.cn/statics/images/bottom/bottom-icon-03.png" /></td> -->
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/1-ewm.jpg" width="70"/><br/><span style="font-size: 12px;">CCTD中国煤炭市场网<br/>官方微信公众号</span></td>
# <!-- <td valign="top" align="center"><img src="https://www.cctd.com.cn/statics/images/bottom/bottom-icon-04.png" /></td> -->
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/4-WB.jpg" width="70"/><br/><span style="font-size: 12px;">CCTD中国煤炭市场网<br/>官方微博</span></td>
# <!-- <td valign="top" align="center"><img src="https://www.cctd.com.cn/statics/images/bottom/bottom-icon-05.png" /></td> -->
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/2-APP.jpg" width="70"/><br/><span style="font-size: 12px;">CCTD中国煤炭市场网<br/>官方APP</span></td>
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/7-XCK.jpg" width="70"/><br/><span style="font-size: 12px;">许传坤 软件部总经理<br/>煤炭运销软件</span></td>
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/8-XWH.jpg" width="70"/><br/><span style="font-size: 12px;">许文辉 市场部副总经理<br/>无人值守磅房系统</span></td>
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/3-LXL.jpg" width="70"/><br/><span style="font-size: 12px;">李小龙 市场部副总经理<br/>煤焦钢市场分析</span></td>
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/6-MNj.jpg" width="70"/><br/><span style="font-size: 12px;">苗纳爵 市场部高级经理<br/>港口煤炭市场分析</span></td>
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/5-MLN.jpg" width="70"/><br/><span style="font-size: 12px;">马丽娜 市场部高级经理<br/>VIP会员服务</span></td>
# <td align="center"><img src="https://www.cctd.com.cn/statics/images/0418/9-ZX.jpg" width="70"/><br/><span style="font-size: 12px;">张鑫 智慧物流事业部<br/>智慧物流产品</span></td>
# </tr>
# </table>
# <div class="zhuti1" style="width: 1350px;">
# <div class="oh">
# <div class="yqlj">
# <div class="zhuti1" style="border-top: 1px solid #FFFFFF; border-bottom: 1px solid #FFFFFF; padding: 10px 0px; margin: 20px 0px; overflow: hidden;width: 1350px;">
# <div style="float: left; height: 20px; line-height: 20px; font-size: 12px; width: 300px;">
# <img src="https://www.cctd.com.cn/statics/images/bottom/bottom-icon-05.png" style="display: block; margin-right: 10px; float: left;" width="20"/><a href="http://www.cctda.org.cn/" target="_blank">中国煤炭运销协会</a><a href="http://www.coalchina.org.cn/" target="_blank">国家煤炭工业网</a>
#
#
# 						<!-- <a href="http://www.cnendata.com/">煤炭大数据</a> -->
# </div>
# <div class="ylxlk" style="float: right;">
# <!--<select name="yl" onchange="window.open(this.options[this.selectedIndex].value,'_blank')">
# 																			<option value="#">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;========政府有关部门========</option>
# 											</select>-->
# <select name="yl" onchange="window.open(this.options[this.selectedIndex].value,'_blank')">
# <option value="#">行业网站</option>
# <!-- <option value="http://www.imcec.cn/">内蒙古煤炭交易中心</option>
# 							<option value="http://www.exbulk.com/">天津港散货交易市场</option> -->
# <option value="http://www.ctctc.com/">中国(太原)煤炭交易中心</option>
# <option value="http://www.pymeitan.com/">盘云煤炭交易网 </option>
# </select>
# <select name="yl" onchange="window.open(this.options[this.selectedIndex].value,'_blank')">
# <option value="#">资讯媒体</option>
# <option value="http://www.ce.cn/cysc/ny">中国经济网</option>
# <option value="http://www.energy.hc360.com/">慧聪网能源行业</option>
# <option value="http://ygbid.com/"> 阳光采招网</option>
# </select>
# <select name="yl" onchange="window.open(this.options[this.selectedIndex].value,'_blank')">
# <option value="#">煤炭企业</option>
# <option value="http://www.zglayx.com">潞安集团运销总公司</option>
# <option value="http://www.zglayx.com">广州珠江电力燃料有限公司</option>
# </select>
# <div class="cb">
# </div>
# </div>
# </div>
# </div>
# <div class="about_we">
# <ul>
# <!-- <li><a href="list-193-1.html">关于我们</a></li>
# 					<li>丨</li>
# 					<li><a href="index.php?m=content&c=index&a=lists&catid=5">招贤纳聘</a></li>
# 					<li>丨</li>
# 					<li><a onclick="this.style.behavior='url(#default#homepage)';this.setHomepage('http://www.cctd.com.cn')" href="http://www.cctd.com.cn">设置首页</a></li>
# 					<li>丨</li>
# 					<li><a href="list-193-1.html">联系方式</a></li>
# 					<li>丨</li>
# 					<li><a href="#">网站导航</a></li>
# 					<li>丨</li>
# 					<li><a href="index.php?m=link">友情链接</a></li> -->
# <li>      主办单位：北京中煤时代科技发展有限公司      CCTD中国煤炭市场网      版权所有      未经许可不得转载
# 					</li>
# </ul>
# </div>
# <table border="0" cellpadding="0" cellspacing="0" style="width: 555px; margin: 0 auto; display: block;">
# <tr>
# <td align="center" width="10%">
# <a href="http://www.hd315.gov.cn/beian/view.asp?bianhao=010202010053100312" target="_blank"><img alt="CCTD中国煤炭市场网" src="https://www.cctd.com.cn/statics/images/biaoshi.gif"/></a>
# </td>
# <td align="left" width="90%">
# <p>copyright 2009 cctd.com.cn All rights Reserved</p>
# <p style="white-space:nowrap;">京ICP备020447号电信业务审批[2002]字第
# 							608609号      京公网安备11010602005267号</p>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <!-- <div style="position: fixed; right: 80px; bottom: 100px;" id="zhaopin">
# 	<div><img src="https://www.cctd.com.cn/statics/images/wxxcx.png" width="180"></div>
# 	<div style="text-align: center;"><img src="https://www.cctd.com.cn/statics/images/gfwb.png" width="180"></div>
# 	<a id="clos" style="float: right; font-size: 12px;">关闭</a>
# </div> -->
# <script type="text/javascript">
# 	var url = window.location.href;
# 	if (url.indexOf("list-167-1") != -1) { //判断url地址中是否包含link字符串
# 		document.getElementById("zhaopin").style.display = 'none';
#
# 	} else {
#
# 	}
#
# 	$("#clos").click(function() {
# 		if ($("#zhaopin").css("display") == "none") {
# 			$("#zhaopin").show(100);
# 		} else {
# 			$("#zhaopin").hide(100);
# 		}
# 	});
# </script>
# <!-- <p id="back-to-top"><span class="gfwx" id="weixin">官方<br />微信</span><span class="zxkf">在线<br />客服</span><span
# 				class="kffl" id="bjkf_b">北京<br />客服</span><span class="kffl" id="tykf_b">太原<br />客服</span><span
# 				class="kffl" id="qhdkf_b">秦皇岛<br />客服</span><span class="kffl" id="jlqz_b">交流<br />群组</span><span
# 				class="jdrx" id="jdrx_b">监督<br />热线</span><a href="#top"><span></span>返回顶部</a></p> -->
# <p id="back-to-top"><a href="#top"><span></span>返回顶部</a></p>
# <div class="ycxf"><img alt="中国煤炭市场网" src="https://www.cctd.com.cn/statics/images/ewm.jpg" style="display:none"/></div>
# <script>
# 	$("#weixin,.ycxf img").hover(function() {
# 		$(".ycxf img").show();
# 	}, function() {
# 		$(".ycxf img").hide();
# 	})
# 	$("#bjkf_b,.bjkf").hover(function() {
# 		$(".bjkf").show();
# 	}, function() {
# 		$(".bjkf").hide();
# 	})
# 	$("#tykf_b,.tykf").hover(function() {
# 		$(".tykf").show();
# 	}, function() {
# 		$(".tykf").hide();
# 	})
# 	$("#qhdkf_b,.qhdkf").hover(function() {
# 		$(".qhdkf").show();
# 	}, function() {
# 		$(".qhdkf").hide();
# 	})
# 	$("#jlqz_b,.jlqz").hover(function() {
# 		$(".jlqz").show();
# 	}, function() {
# 		$(".jlqz").hide();
# 	})
# 	$("#jdrx_b,.jdrx_a").hover(function() {
# 		$(".jdrx_a").show();
# 	}, function() {
# 		$(".jdrx_a").hide();
# 	})
# </script>
# <script src="https://www.cctd.com.cn/statics/js/jQuery-jcMarquee.js" type="text/javascript"></script>
# <script>
# 	/*滚动新闻js*/
# 	$(function() {
# 		$('#Marquee_x').jcMarquee({
# 			'marquee': 'x',
# 			'margin_right': '10px',
# 			'speed': 20
# 		});
# 		// DIVCSS5提示：10px代表间距，第二个20代表滚动速度
# 	});
# </script>
# <script type="text/javascript">
# 	/*轮播图片js*/
# 	$(function() {
# 		var oFocus = $('#focus'),
# 			oRight = oFocus.find('.right'),
# 			oLeft = oFocus.find('.left'),
# 			aRLi = oRight.find('li'),
# 			aLLi = oLeft.find('li'),
# 			index = 0,
# 			timer = null;
# 		aRLi.hover(function() {
# 			index = $(this).index()
# 			$(this).addClass('active').siblings().removeClass();
# 			aLLi.eq(index).addClass('active').siblings().removeClass();
# 			aLLi.eq(index).stop().animate({
# 				'opacity': 1
# 			}, 300).siblings().stop().animate({
# 				'opacity': 0
# 			}, 300);
# 			stopFoucs();
# 		})
# 		oLeft.mouseenter(function() {
# 			stopFoucs();
# 		}).mouseleave(function() {
# 			startFocus();
# 		});
# 		timer = setInterval(function() {
# 			startFocus();
# 		}, 5000);
#
# 		function startFocus() {
# 			index++;
# 			index = index > aRLi.size() - 1 ? 0 : index;
# 			aLLi.eq(index).addClass('active').siblings().removeClass();
# 			aLLi.eq(index).stop().animate({
# 				'opacity': 1
# 			}, 300).siblings().stop().animate({
# 				'opacity': 0
# 			}, 300);
# 			aRLi.eq(index).addClass('active').siblings().removeClass();
# 		}
#
# 		function stopFoucs() {
# 			clearInterval(timer);
# 		}
# 	})
# </script>
# <script>
# 	/*第一种形式 第二种形式 更换显示样式*/
# 	function setTab(name, cursel, n) {
# 		for (i = 1; i <= n; i++) {
# 			var menu = document.getElementById(name + i);
# 			var con = document.getElementById("con_" + name + "_" + i);
# 			menu.className = i == cursel ? "hover" : "";
# 			con.style.display = i == cursel ? "block" : "none";
# 		}
# 	}
# </script>
# <script type="text/javascript">
# 	$(document).ready(function() {
# 		//首先将#back-to-top隐藏
# 		//$("#back-to-top").hide();
# 		//当滚动条的位置处于距顶部100像素以下时，跳转链接出现，否则消失
# 		$(function() {
# 			$(window).scroll(function() {
# 				if ($(window).scrollTop() > 100) {
# 					$("#back-to-top").fadeIn(1500);
# 				}
# 				/* else {
# 				                    $("#back-to-top").fadeOut(1500);
# 				                }*/
# 			});
# 			//当点击跳转链接后，回到页面顶部位置
# 			$("#back-to-top").click(function() {
# 				$('body,html').animate({
# 					scrollTop: 0
# 				}, 1000);
# 				return false;
# 			});
# 		});
# 	});
# </script>
# <script>
# 	$(".spxw img").attr("alt", "中国煤炭市场网");
# </script>
# <script type="text/javascript">
# 	$(function() {
# 		$(".picbig").each(function(i) {
# 			var cur = $(this).find('.img-wrap').eq(0);
# 			var w = cur.width();
# 			var h = cur.height();
# 			$(this).find('.img-wrap img').LoadImage(true, w, h, 'https://www.cctd.com.cn/statics/images/msg_img/loading.gif');
# 		});
# 	})
# </script>
# </body>
# </html>
# <!-- foot结束 -->

# %%
all_tables = soup.find_all('table')

# %%
i = 9
all_tables[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13272\357466764.py in <module>
#       1 i = 9
# ----> 2 all_tables[i]
#
# IndexError: list index out of range

# %%
#table1 = soup.find('table', id='main_table_countries_today')
table1 = all_tables[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13272\3141686525.py in <module>
#       1 #table1 = soup.find('table', id='main_table_countries_today')
# ----> 2 table1 = all_tables[i]
#
# IndexError: list index out of range

# %%
headers = []
for i in table1.find_all('th'):
    title = i.text
    headers.append(title)

# %%
mydata = pd.DataFrame(columns = headers)

# %%
for j in table1.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [i.text for i in row_data]
    length = len(mydata)
    mydata.loc[length] = row

# %%
mydata
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mydata.to_excel('table.xlsx')
