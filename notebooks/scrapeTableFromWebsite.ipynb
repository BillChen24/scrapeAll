# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Create an URL object
url = 'http://113.57.190.228:8001/web/Report/RiverReport'
# Create object page
page = requests.get(url, verify = False)

# %%
soup = BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <title>江河水情报表</title>
# <style type="text/css">
#         html, body {
#         width:100%;
#         height:100%;
#         }
#         ::-webkit-scrollbar {
#             /*滚动条整体样式*/
#             width: 5px; /*高宽分别对应横竖滚动条的尺寸*/
#             height: 5px;
#         }
#
#         ::-webkit-scrollbar-thumb {
#             /*滚动条里面小方块*/
#             border-radius: 3px;
#             background-color: rgba(179, 234, 255, 1);
#             background-image: -webkit-linear-gradient( 45deg, rgba(255, 255, 255, 0.2) 25%, transparent 25%, transparent 50%, rgba(255, 255, 255, 0.2) 50%, rgba(255, 255, 255, 0.2) 75%, transparent 75%, transparent );
#         }
#
#         ::-webkit-scrollbar-track {
#             /*滚动条里面轨道*/
#             box-shadow: inset 0 0 5px rgba(0, 0, 0, 0.2);
#             background: #ededed;
#             border-radius: 3px;
#         }
#     </style>
# <!--[if IE]><link href="/Content/css/hack/ie.css" rel="stylesheet" type="text/css" /><![endif]-->
# <!--加载960CSS框架-->
# <link href="/Content/css/960/fluid/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/960/fluid/text.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/960/fluid/grid.css" rel="stylesheet" type="text/css"/>
# <!--[if IE 6]><link href="/Content/css/960/fluid/ie6.css" rel="stylesheet" type="text/css" /><![endif]-->
# <!--[if IE 7]><link href="/Content/css/960/fluid/ie.css"  rel="stylesheet" type="text/css" /><![endif]-->
# <!--加载按钮CSS-->
# <link href="/Content/css/btns/css3btn.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/btns/sexybuttons.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/Site.css" rel="stylesheet" type="text/css"/>
# <!--加载组件CSS-->
# <link href="/Content/js/jquery-plugin/showloading/showLoading.css" rel="stylesheet" type="text/css"/>
# <!--加载样式修正CSS-->
# <link href="/Content/css/hack/fix.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/js/jquery-easyui-1.5.2/themes/gray/easyui.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/js/jquery-easyui-1.5.2/themes/icon.css" rel="stylesheet" type="text/css"/>
# <!--加载jQuery-->
# <script src="/Content/js/jquery/jquery-1.11.3.min.js" type="text/javascript"></script>
# <script src="/Content/js/jQuery.print.js" type="text/javascript"></script>
# <script src="/Content/js/core/common.js" type="text/javascript"></script>
# <script src="/Content/js/export/exportExcel.js" type="text/javascript"></script>
# <script src="/Content/js/library?v=bAa9fn9nwwxUUDIGZ3yQScXdl4RWfrcV-33b9K3yybg1"></script>
# <script type="text/javascript">
#         $(function () {
#
#         $("#a_print").bind("click", function () {
#             //$("#div_report").jqprint();
#             var title = $("#title").html();
#             $('#gridlist').printArea(title);
#
#         });
#         $("#a_export").bind("click", function () {
#
#             //var options = $('#gridlist').datagrid("options");
#             //var columns = options.columns;
#             //$.post("/Home/ExportToExcel", { "JsonColunms": JSON.stringify(columns), "JsonData": "", "JsonTitle": "" }, null);
#             ExportExcel($("#gridlist"));
#         });
#         $("#a_print1").bind("click", function () {
#             //$("#div_report").jqprint();
#             $('#detail').printArea('');
#         });
#         $("#a_export1").bind("click", function () {
#              ExportExcel($("#gridlist"));
#         });
#         $("#a_print2").bind("click", function () {
#             $('#data').printArea('');
#         });
#         $("#a_export2").bind("click", function () {
#             ExportExcel($("#data"));
#         });
#     });
#
#     </script>
# </head>
# <body class="easyui-layout" data-ng-options="fit:true" scroll="no">
# <div class="easyui-panel" data-options="fit:true,border:false">
# <div class="easyui-layout" data-options="fit:true,border:false" style="margin:auto;">
# <div region="north" style="overflow:hidden; border:0px;">
# <div id="divToolBarCondi" style="background-color:white;border:0px;">
# <div class="container_12" id="condition">
# <table>
# <tr>
# <td>时间：</td>
# <td><input class="easyui-datetimespinner" data-options="formatter:com.formatDate,parser:com.parser,selections:[[0,4],[5,7],[8,10]]" id="start" style="width:100px;"/><input class="easyui-timespinner" id="starth" style="width:60px;" value="08:00"/></td>
# <td><a class="button button-orange" id="a_search" style="margin:0 15px;">查询</a></td>
# </tr>
# </table>
# <div class="prefix_10">
# <a class="button button-green" href="#" id="a_print" style="margin:0 15px;">打印</a>
# <a class="button button-green" href="#" id="a_export">导出</a>
# </div>
# <div style="height:1px; background-color:#0094ff; width:98%;margin-top:0px;"></div>
# </div>
# </div>
# </div>
# <div id="div_report" region="center">
# <table id="reporttitle_table" style="width:100%; margin:auto;background-color:white;">
# <tr>
# <th></th>
# <th align="center"><span class="report-title" id="title"></span></th>
# <th></th>
# </tr>
# <tr>
# <td align="left" class="report-source">湖北省水文水资源中心 </td>
# <td align="center"><span class="report-subtitle" id="reportSecondTitle"> </span></td>
# <td align="right" class="report-unit">单位（水位：m；流量m³/s）</td>
# </tr>
# </table>
# <table id="gridlist" style="width:100%;height:100%;border:1px solid #808080;" title=""></table>
# </div>
# </div>
# </div>
# <input id="Field" type="hidden"/>
# <script src="/Content/js/jquery-easyui-1.5.2/jquery.easyui.min.js" type="text/javascript"></script>
# <script src="/Content/js/jquery-easyui-1.5.2/locale/easyui-lang-zh_CN.js"></script>
# <script src="/Content/js/jquery-easyui-1.5.2/easyloader.js?locale=zh_CN&amp;theme=gray" type="text/javascript"></script>
# <script type="text/javascript">
#         $(function () {
#             var date = com.formatDate(new Date());
#             var hh = utils.formatDate(new Date(), 'hh');
#             $('#start').datetimespinner({
#                 value: date
#             });
#             //$('#starth').timespinner({
#             //    value: hh
#             //});
#             gridList();
#             $("#a_search").bind("click", search);
#             search();
#
#         });
#
#         function gridList() {
#             $('#gridlist').datagrid({
#                 striped: true,
#                 fitColumns: true,
#                 fit: true,
#                 singleSelect: true,
#                 nowrap: false,
#                 pagination: false,
#                 toolbar: '#reporttitle_table',
#                 border: false,
#                 columns: [[
#                     { field: 'RVNM', title: '河名', width: '6.5%', align: 'center', styler: GreenCL },
#                     { field: 'STNM', title: '站名', width: '7%', align: 'center', styler: GreenCL },
#                     { field: 'Z', title: '水位', width: '5.5%', align: 'center', styler: BJRedCL },//, formatter: changevalue
#                     { field: 'WPTN', title: '水势', width: '4.5%', align: 'center', formatter: changewptn, styler: RedCL },
#                     { field: 'YZ', title: '比昨日</br>+涨-落', width: '5%', align: 'center', styler: RedCL },//, formatter: changevalue
#                     { field: 'Q', title: '流量', width: '5.5%', align: 'center', styler: RedCL },
#                     { field: 'FRZ', title: '设防</br>水位', width: '5.5%', align: 'center', styler: changeSFcolor },//, formatter: changeTZvalue
#                     { field: 'WRZ', title: '警戒</br>水位', width: '5.5%', align: 'center', styler: changeSFcolor },//, formatter: changeTZvalue
#                     { field: 'GRZ', title: '保证</br>水位', width: '5.5%', align: 'center', styler: changeSFcolor },//, formatter: changeTZvalue
#                    { field: 'RVNM1', title: '河名', width: '6.5%', align: 'center', styler: GreenCL },
#                    { field: 'STNM1', title: '站名', width: '7.5%', align: 'center', styler: GreenCL },
#                    { field: 'Z1', title: '水位', width: '5.5%', align: 'center', styler: BJRedCL2 },//, formatter: changevalue
#                    { field: 'WPTN1', title: '水势', width: '4.5%', align: 'center', formatter: changewptn, styler: RedCL },
#                    { field: 'YZ1', title: '比昨日</br>+涨-落', width: '5%', align: 'center', styler: RedCL },//, formatter: changevalue
#                    { field: 'Q1', title: '流量', width: '5.5%', align: 'center', styler: RedCL },
#                    { field: 'FRZ1', title: '设防</br>水位', width: '5.5%', align: 'center', styler: changeSFcolor },//, formatter: changeTZvalue
#                    { field: 'WRZ1', title: '警戒</br>水位', width: '5.5%', align: 'center', styler: changeSFcolor },//, formatter: changeTZvalue
#                    { field: 'GRZ1', title: '保证</br>水位', width: '5.5%', align: 'center', styler: changeSFcolor }//, formatter: changeTZvalue
#
#                 ]],
#                 onLoadSuccess: function () {
#                     mergeCellsByField("gridlist", "RVNM,RVNM1");
#                 }
#
#
#
#             });
#
#         }
#         //设置实时水位的颜色
#         function BJRedCL(value, row, index) {
#             var Z = row.Z;
#             var FRZ = row.FRZ;
#             var WRZ = row.WRZ;
#             var MAXZ = row.MAXZ;
#             var GRZ = row.GRZ;
#             //if (Z != "" && Z != null) {
#             //    if (FRZ != "" && FRZ != null) {
#             //        if ((parseFloat(Z) - parseFloat(FRZ)) > 0)
#             //            return "background-color:#FFCC99;color:yellow;";
#             //    }
#             //    if (WRZ != "" && WRZ != null) {
#             //        if ((parseFloat(Z) - parseFloat(WRZ)) > 0)
#             //            return "background-color:#FFCC99;color:orange;";
#             //    }
#             //    if (MAXZ != "" && MAXZ != null) {
#             //        if ((parseFloat(Z) - parseFloat(MAXZ)) > 0)
#             //            return "background-color:#FFCC99;color:red;";
#             //    }
#
#             //}
#
#             //return "background-color:#FFCC99;";
#             var cFRZ = 0, cWRZ = 0, cMAXZ = 0, cBZZ = 0;
#             if (Z != "" && Z != null) {
#                 if (FRZ != "" && FRZ != null) {
#                     cFRZ = parseFloat(Z) - parseFloat(FRZ);
#                 }
#                 if (WRZ != "" && WRZ != null) {
#                     cWRZ = parseFloat(Z) - parseFloat(WRZ);
#                 }
#                 if (MAXZ != "" && MAXZ != null) {
#                     cMAXZ = parseFloat(Z) - parseFloat(MAXZ);
#                 }
#                 if (GRZ != "" && GRZ != null) {
#                     cBZZ = parseFloat(Z) - parseFloat(GRZ);
#                 }
#                 if (cFRZ > 0) {
#                     if (cWRZ > 0) {
#                         if (cBZZ < 0)
#                             return "background-color:#FFCC99;color:#e0861a;font-weight:bold;";
#                         else if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                     }
#                     else {
#                         if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                         else if (cBZZ < 0)
#                             return "background-color:#FFCC99;color:blue;font-weight:bold;";
#                     }
#                     //return "background-color:#FFCC99;color:blue;font-weight:bold;";
#                 }
#                 else {
#                     if (cWRZ > 0) {
#                         if (cBZZ < 0)
#                             return "background-color:#FFCC99;color:#e0861a;font-weight:bold;";
#                         else if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                     }
#                     else {
#                         if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                     }
#                 }
#
#             }
#
#             return "background-color:#FFCC99;";
#         }
#         function BJRedCL2(value, row, index) {
#             var Z = row.Z1;
#             var FRZ = row.FRZ1;
#             var WRZ = row.WRZ1;
#             var MAXZ = row.MAXZ1;
#             var GRZ = row.GRZ1;
#             var cFRZ = 0, cWRZ = 0, cMAXZ = 0, cBZZ = 0;
#             if (Z != "" && Z != null) {
#                 if (FRZ != "" && FRZ != null) {
#                     cFRZ = parseFloat(Z) - parseFloat(FRZ);
#                 }
#                 if (WRZ != "" && WRZ != null) {
#                     cWRZ = parseFloat(Z) - parseFloat(WRZ);
#                 }
#                 if (MAXZ != "" && MAXZ != null) {
#                     cMAXZ = parseFloat(Z) - parseFloat(MAXZ);
#                 }
#                 if (GRZ != "" && GRZ != null) {
#                     cBZZ = parseFloat(Z) - parseFloat(GRZ);
#                 }
#                 if (cFRZ > 0) {
#                     if (cWRZ > 0) {
#                         if (cBZZ < 0)
#                             return "background-color:#FFCC99;color:#e0861a;font-weight:bold;";
#                         else if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                     }
#                     else {
#                         if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                         else if (cBZZ < 0)
#                             return "background-color:#FFCC99;color:blue;font-weight:bold;";
#                     }
#                     //return "background-color:#FFCC99;color:blue;font-weight:bold;";
#                 }
#                 else {
#                     if (cWRZ > 0) {
#                         if (cBZZ < 0)
#                             return "background-color:#FFCC99;color:#e0861a;font-weight:bold;";
#                         else if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                     }
#                     else {
#                         if (cBZZ > 0)
#                             return "background-color:#FFCC99;color:red;font-weight:bold;";
#                     }
#                 }
#
#             }
#
#             return "background-color:#FFCC99;";
#         }
#         //设置设防水位颜色
#         function changeSFcolor(value, row, index) {
#             //if (value != "--") {
#             //    return 'background-color:#99CCFF;color:blue;';
#             //}
#             return 'background-color:#99CCFF;';
#         }
#         //设置警戒水位颜色
#         function changeJJcolor(value, row, index) {
#             //if (value != "--") {
#                 return 'background-color:#99CCFF;color:yellow;';
#             //}
#         }
#         //设置最高水位颜色
#         function changeZGcolor(value, row, index) {
#             //if (value != "--") {
#                 return 'background-color:#99CCFF;color:red;';
#             //}
#         }
#         function changeTZvalue(val, row) {
#             var s = "--";
#             if (val != null) {
#
#                 var f = parseFloat(val);
#                 if (isNaN(f)) {
#                     return "--";
#                 }
#                 var f = Math.round(val * 100) / 100;
#                 s = f.toString();
#                 var rs = s.indexOf('.');
#                 if (rs < 0) {
#                     rs = s.length;
#                     s += '.';
#                 }
#                 while (s.length <= rs + 2) {
#                     s += '0';
#
#                 }
#             }
#             return s;
#         }
#         function search() {
#             $("#title").html("湖北省常用水情报表");//江河水情报表
#             var date = $("#start").val() + " " + $("#starth").val();
#             $("#reportSecondTitle").html(utils.formatDate(date, 'yyyy年MM月dd日 hh时'));
#             com.ajax({
#                 type: 'get',
#                 url: '/Web/Report/GetRiverData',
#                 data: {
#                     date: date
#
#                 },
#                 success: function (d) {
#                     $("#gridlist").datagrid('loadData', d.rows);
#                 }
#
#             });
#         }
#     </script>
# <!--加载图标库CSS-->
# <link href="/Content/css/icon/icon.css" rel="stylesheet" type="text/css"/>
# </body>
# </html>

# %%
all_tables = soup.find_all('table')

# %%
all_tables
# Out:
# [<table>
#  <tr>
#  <td>时间：</td>
#  <td><input class="easyui-datetimespinner" data-options="formatter:com.formatDate,parser:com.parser,selections:[[0,4],[5,7],[8,10]]" id="start" style="width:100px;"/><input class="easyui-timespinner" id="starth" style="width:60px;" value="08:00"/></td>
#  <td><a class="button button-orange" id="a_search" style="margin:0 15px;">查询</a></td>
#  </tr>
#  </table>,
#  <table id="reporttitle_table" style="width:100%; margin:auto;background-color:white;">
#  <tr>
#  <th></th>
#  <th align="center"><span class="report-title" id="title"></span></th>
#  <th></th>
#  </tr>
#  <tr>
#  <td align="left" class="report-source">湖北省水文水资源中心 </td>
#  <td align="center"><span class="report-subtitle" id="reportSecondTitle"> </span></td>
#  <td align="right" class="report-unit">单位（水位：m；流量m³/s）</td>
#  </tr>
#  </table>,
#  <table id="gridlist" style="width:100%;height:100%;border:1px solid #808080;" title=""></table>]

# %%
i = 9
all_tables[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13272\357466764.py in <module>
#       1 i = 9
# ----> 2 all_tables[i]
#
# IndexError: list index out of range

# %%
#table1 = soup.find('table', id='main_table_countries_today')
table1 = all_tables[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13272\3141686525.py in <module>
#       1 #table1 = soup.find('table', id='main_table_countries_today')
# ----> 2 table1 = all_tables[i]
#
# IndexError: list index out of range

# %%
headers = []
for i in table1.find_all('th'):
    title = i.text
    headers.append(title)

# %%
mydata = pd.DataFrame(columns = headers)

# %%
for j in table1.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [i.text for i in row_data]
    length = len(mydata)
    mydata.loc[length] = row

# %%
mydata
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mydata.to_excel('table.xlsx')
